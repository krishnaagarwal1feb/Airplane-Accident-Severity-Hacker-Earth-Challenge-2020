# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnaagarwal1feb/Airplane-Accident-Severity-Hacker-Earth-Challenge-2020/blob/master/merge_player_stats_to_ball_by_ball_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
bowler = pd.read_csv('bowlers_data(08-20).csv')
batsman = pd.read_csv('batsmans_data(08-20).csv')
ball_df = pd.read_csv('IPL Ball-by-Ball 2008-2020.csv').drop(['dismissal_kind', 'player_dismissed','extras_type','fielder','batsman_runs'],1)

# %% [markdown]
# # New Section

# %%
ball_df.rename({'inning': 'innings_number'},axis= 1,inplace = True)

# %%
ball_df
# Out:
#              id  ...                 bowling_team
# 0        335982  ...  Royal Challengers Bangalore
# 1        335982  ...  Royal Challengers Bangalore
# 2        335982  ...  Royal Challengers Bangalore
# 3        335982  ...  Royal Challengers Bangalore
# 4        335982  ...  Royal Challengers Bangalore
# ...         ...  ...                          ...
# 193463  1237181  ...               Mumbai Indians
# 193464  1237181  ...               Mumbai Indians
# 193465  1237181  ...               Mumbai Indians
# 193466  1237181  ...               Mumbai Indians
# 193467  1237181  ...               Mumbai Indians
#
# [193468 rows x 13 columns]

# %%
batsman.drop(['Unnamed: 0','Team','opposition_team','Ground','date'],1,inplace = True)

# %%
batsman
# Out:
#             id      batsman  batsman_runs  ...  innings_number  50s  100s
# 0       335982    AA Noffke             9  ...               2    0     0
# 1       335982      B Akhil             0  ...               2    0     0
# 2       335982  BB McCullum           158  ...               1    0     1
# 3       335982     CL White             6  ...               2    0     0
# 4       335982    DJ Hussey            12  ...               1    0     0
# ...        ...          ...           ...  ...             ...  ...   ...
# 12118  1237181      RR Pant            56  ...               1    1     0
# 12119  1237181     S Dhawan            15  ...               1    0     0
# 12120  1237181     SA Yadav            19  ...               2    0     0
# 12121  1237181   SO Hetmyer             5  ...               1    0     0
# 12122  1237181      SS Iyer            65  ...               1    1     0
#
# [12123 rows x 10 columns]

# %%
ball_df.drop_duplicates()
# Out:
#              id  ...                 bowling_team
# 0        335982  ...  Royal Challengers Bangalore
# 1        335982  ...  Royal Challengers Bangalore
# 2        335982  ...  Royal Challengers Bangalore
# 3        335982  ...  Royal Challengers Bangalore
# 4        335982  ...  Royal Challengers Bangalore
# ...         ...  ...                          ...
# 193463  1237181  ...               Mumbai Indians
# 193464  1237181  ...               Mumbai Indians
# 193465  1237181  ...               Mumbai Indians
# 193466  1237181  ...               Mumbai Indians
# 193467  1237181  ...               Mumbai Indians
#
# [193467 rows x 13 columns]

# %%
ball_df.shape
# Out:
# (193468, 13)

# %%
merged_batsman = ball_df.merge(batsman, how = 'inner', on = ['id','innings_number', 'batsman'])

# %%
#merged_batsman_outer = ball_df.merge(batsman, how = 'outer', on = ['id','innings_number', 'batsman'])

# %%
merged_batsman.shape
# Out:
# (193427, 20)

# %%
#merged_batsman.equals(merged_batsman_outer)

# %%
#pd.concat([merged_batsman,merged_batsman_outer]).drop_duplicates(keep=False)

# %%
merged_batsman.isna().sum()
# Out:
# id                  0
# innings_number      0
# over                0
# ball                0
# batsman             0
# non_striker         0
# bowler              0
# extra_runs          0
# total_runs          0
# non_boundary        0
# is_wicket           0
# batting_team        0
# bowling_team      191
# batsman_runs        0
# balls_faced         0
# strike_rate         0
# Boundary Fours      0
# Boundary Sixes      0
# 50s                 0
# 100s                0
# dtype: int64

# %%
ball_df.columns
# Out:
# Index(['id', 'innings_number', 'over', 'ball', 'batsman', 'non_striker',
#        'bowler', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
batsman.columns
# Out:
# Index(['id', 'batsman', 'batsman_runs', 'balls_faced', 'strike_rate',
#        'Boundary Fours', 'Boundary Sixes', 'innings_number', '50s', '100s'],
#       dtype='object')

# %%
for x in list(ball_df.columns):
  if x in list(batsman.columns):
    print(x)
# Out:
# id
# innings_number
# batsman

# %%
bowler.drop(['Unnamed: 0','Team','opposition_team','Ground','date'],1,inplace = True)

# %%
df = merged_batsman.merge(bowler, how = 'inner', on = ['id','innings_number', 'bowler'])

# %%
df = df.drop_duplicates()
df
# Out:
#              id  innings_number  ...  wickets_taken  economy_rate
# 0        335982               1  ...            1.0         10.70
# 1        335982               1  ...            1.0         10.70
# 2        335982               1  ...            1.0         10.70
# 3        335982               1  ...            1.0         10.70
# 4        335982               1  ...            1.0         10.70
# ...         ...             ...  ...            ...           ...
# 193422  1237181               2  ...            1.0         12.71
# 193423  1237181               2  ...            1.0         12.71
# 193424  1237181               2  ...            1.0         12.71
# 193425  1237181               2  ...            1.0         12.71
# 193426  1237181               2  ...            1.0         12.71
#
# [193426 rows x 24 columns]

# %%
df.to_csv('final_data.csv')
